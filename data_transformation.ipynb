# %% [markdown]
# # Data transformation
#
# This jupyter notebook contains open source code for transforming a data from the Australian Institute of Health and Welfare (AIHW). AIHW (https://www.aihw.gov.au) is a health and welfare statistics agency in Australia where provides a wide range of health and welfare data collections. We first download data tables: Employment supplementary data tables, 2020” from “People with disability in Australia” collection [1] by AIHW. This data collection contains information about people aged 15 and over living in households, by age group, gender, disability status, and labour force status in 2018.

# %% [markdown]
# ## Import library

# %%
import pandas as pd

# %% [markdown]
# ## Download data

# %% [markdown]
# Download "Employment supplementary data tables, 2020” from “People with disability in Australia” collection in AIHW (https://www.aihw.gov.au/reports/disability/people-with-disability-in-australia/data).

# %%
input_file = 'aihw-dis-72-employment.xlsx'
output_file = 'generated_data/transformed_data.csv'

# %% [markdown]
# ## Read data

# %%
df = pd.read_excel(input_file, sheet_name = 'Table EMPL1', skiprows=1, header=0)
df
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                  Labour force and employment status
# 2                                                 NaN
# 3                              In the labour force(d)
# 4                                         Employed(e)
# 5                          Employed working full-time
# 6                          Employed working part-time
# 7                                          Unemployed
# 8                          Not in the labour force(f)
# 9                                               Total
# 10                                                NaN
# 11                             In the labour force(d)
# 12                                        Employed(e)
# 13                         Employed working full-time
# 14                         Employed working part-time
# 15                                         Unemployed
# 16                         Not in the labour force(f)
# 17                                              Total
# 18                                                NaN
# 19                             In the labour force(d)
# 20                                        Employed(e)
# 21                         Employed working full-time
# 22                         Employed working part-time
# 23                                         Unemployed
# 24                         Not in the labour force(f)
# 25                                              Total
# 26                                                NaN
# 27  * Estimate has a relative standard error of 25...
# 28  (a) Collected for people aged 15 and over livi...
# 29  (b) Severe or profound core activity limitatio...
# 30  (c) Disability with status other than severe o...
# 31  (d) People who are employed or unemployed. Lab...
# 32  (e) Employment rate (employment to working-age...
# 33  (f) People who are not employed or unemployed....
# 34  Note: Figures are rounded and components may n...
# 35  Source: ABS (Australian Bureau of Statistics) ...
#
#                                  Unnamed: 1 Unnamed: 2   Unnamed: 3  \
# 0   With disability—\nsevere or profound(b)        NaN          NaN
# 1                          Estimate\n('000)          %       95% CI
# 2                                     Males        NaN          NaN
# 3                                      76.4         31  (25.8–36.2)
# 4                                      65.2       26.5  (21.7–31.3)
# 5                                      35.9       14.6  (10.5–18.6)
# 6                                      29.4       11.9   (8.9–15.0)
# 7                                      12.6        5.1    (2.8–7.4)
# 8                                     170.3       69.2  (65.1–73.2)
# 9                                     246.2        100          . .
# 10                                  Females        NaN          NaN
# 11                                       61       23.6  (19.6–27.6)
# 12                                     58.2       22.5  (18.6–26.4)
# 13                                     23.7        9.2   (6.3–12.0)
# 14                                     35.7       13.8  (11.0–16.6)
# 15                                      6.6        2.5    (1.2–3.9)
# 16                                    196.7         76  (73.3–78.7)
# 17                                    258.9        100          . .
# 18                                    Total        NaN          NaN
# 19                                    137.2       27.2  (24.1–30.4)
# 20                                    120.2       23.9  (20.6–27.1)
# 21                                     57.4       11.4   (8.9–13.9)
# 22                                     62.4       12.4  (10.3–14.4)
# 23                                     17.4        3.5    (2.3–4.6)
# 24                                    366.1       72.7  (69.6–75.7)
# 25                                    503.8        100          . .
# 26                                      NaN        NaN          NaN
# 27                                      NaN        NaN          NaN
# 28                                      NaN        NaN          NaN
# 29                                      NaN        NaN          NaN
# 30                                      NaN        NaN          NaN
# 31                                      NaN        NaN          NaN
# 32                                      NaN        NaN          NaN
# 33                                      NaN        NaN          NaN
# 34                                      NaN        NaN          NaN
# 35                                      NaN        NaN          NaN
#
#     Unnamed: 4                                    Unnamed: 5 Unnamed: 6  \
# 0          NaN  With disability—\nother disability status(c)        NaN
# 1          NaN                              Estimate\n('000)          %
# 2          NaN                                           NaN        NaN
# 3          NaN                                         486.3       64.3
# 4          NaN                                         437.1       57.8
# 5          NaN                                         323.5       42.8
# 6          NaN                                         111.2       14.7
# 7          NaN                                          50.1        6.6
# 8          NaN                                         268.7       35.5
# 9          NaN                                         756.4        100
# 10         NaN                                           NaN        NaN
# 11         NaN                                           472       59.2
# 12         NaN                                         427.7       53.6
# 13         NaN                                         200.4       25.1
# 14         NaN                                         227.7       28.5
# 15         NaN                                          44.2        5.5
# 16         NaN                                         324.5       40.7
# 17         NaN                                         797.8        100
# 18         NaN                                           NaN        NaN
# 19         NaN                                           960       61.9
# 20         NaN                                           863       55.6
# 21         NaN                                         525.3       33.9
# 22         NaN                                         341.3         22
# 23         NaN                                          94.7        6.1
# 24         NaN                                         591.4       38.1
# 25         NaN                                        1551.5        100
# 26         NaN                                           NaN        NaN
# 27         NaN                                           NaN        NaN
# 28         NaN                                           NaN        NaN
# 29         NaN                                           NaN        NaN
# 30         NaN                                           NaN        NaN
# 31         NaN                                           NaN        NaN
# 32         NaN                                           NaN        NaN
# 33         NaN                                           NaN        NaN
# 34         NaN                                           NaN        NaN
# 35         NaN                                           NaN        NaN
#
#      Unnamed: 7  Unnamed: 8           Unnamed: 9 Unnamed: 10  Unnamed: 11  \
# 0           NaN         NaN  All with disability         NaN          NaN
# 1        95% CI         NaN     Estimate\n('000)           %       95% CI
# 2           NaN         NaN                  NaN         NaN          NaN
# 3   (61.1–67.5)         NaN                562.6        56.1  (53.5–58.7)
# 4   (54.4–61.1)         NaN                500.4        49.9  (47.2–52.6)
# 5   (39.9–45.6)         NaN                358.9        35.8  (33.3–38.3)
# 6   (12.5–16.9)         NaN                  141        14.1  (12.3–15.8)
# 7     (5.2–8.0)         NaN                 63.2         6.3    (5.1–7.5)
# 8   (33.3–37.8)         NaN                440.5          44  (41.6–46.3)
# 9           . .         NaN               1002.2         100          . .
# 10          NaN         NaN                  NaN         NaN          NaN
# 11  (56.4–62.0)         NaN                534.7        50.7  (48.5–52.9)
# 12  (50.8–56.4)         NaN                483.8        45.9  (43.7–48.0)
# 13  (22.9–27.4)         NaN                222.5        21.1  (19.4–22.8)
# 14  (25.8–31.3)         NaN                262.6        24.9  (22.7–27.0)
# 15    (4.3–6.8)         NaN                 50.4         4.8    (3.8–5.7)
# 16  (38.2–43.2)         NaN                519.4        49.2  (47.0–51.5)
# 17          . .         NaN               1054.9         100          . .
# 18          NaN         NaN                  NaN         NaN          NaN
# 19  (59.7–64.0)         NaN               1098.6        53.4  (51.8–55.0)
# 20  (53.4–57.8)         NaN                984.2        47.8  (46.2–49.5)
# 21  (31.9–35.9)         NaN                581.8        28.3  (26.6–29.9)
# 22  (20.3–23.7)         NaN                402.8        19.6  (18.2–20.9)
# 23    (5.1–7.1)         NaN                112.7         5.5    (4.6–6.3)
# 24  (36.3–39.9)         NaN                958.5        46.6  (44.9–48.3)
# 25          . .         NaN               2057.5         100          . .
# 26          NaN         NaN                  NaN         NaN          NaN
# 27          NaN         NaN                  NaN         NaN          NaN
# 28          NaN         NaN                  NaN         NaN          NaN
# 29          NaN         NaN                  NaN         NaN          NaN
# 30          NaN         NaN                  NaN         NaN          NaN
# 31          NaN         NaN                  NaN         NaN          NaN
# 32          NaN         NaN                  NaN         NaN          NaN
# 33          NaN         NaN                  NaN         NaN          NaN
# 34          NaN         NaN                  NaN         NaN          NaN
# 35          NaN         NaN                  NaN         NaN          NaN
#
#     Unnamed: 12         Unnamed: 13 Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0           NaN  Without disability         NaN          NaN          NaN
# 1           NaN    Estimate\n('000)           %       95% CI          NaN
# 2           NaN                 NaN         NaN          NaN          NaN
# 3           NaN              6164.5        88.6  (88.0–89.1)          NaN
# 4           NaN              5899.7        84.8  (84.1–85.4)          NaN
# 5           NaN              4851.5        69.7  (68.8–70.6)          NaN
# 6           NaN              1050.2        15.1  (14.3–15.9)          NaN
# 7           NaN               265.7         3.8    (3.4–4.2)          NaN
# 8           NaN               792.9        11.4  (10.8–12.0)          NaN
# 9           NaN              6957.8         100          . .          NaN
# 10          NaN                 NaN         NaN          NaN          NaN
# 11          NaN                5633        79.7  (79.0–80.3)          NaN
# 12          NaN              5355.9        75.8  (75.1–76.4)          NaN
# 13          NaN              2838.4        40.2  (39.2–41.2)          NaN
# 14          NaN              2515.2        35.6  (34.7–36.5)          NaN
# 15          NaN               277.5         3.9    (3.6–4.3)          NaN
# 16          NaN              1435.5        20.3  (19.5–21.1)          NaN
# 17          NaN              7068.9         100          . .          NaN
# 18          NaN                 NaN         NaN          NaN          NaN
# 19          NaN             11797.9        84.1  (83.7–84.5)          NaN
# 20          NaN             11257.1        80.3  (79.9–80.7)          NaN
# 21          NaN              7691.7        54.8  (54.1–55.6)          NaN
# 22          NaN              3565.8        25.4  (24.8–26.0)          NaN
# 23          NaN               544.2         3.9    (3.6–4.1)          NaN
# 24          NaN              2226.9        15.9  (15.4–16.4)          NaN
# 25          NaN             14025.3         100          . .          NaN
# 26          NaN                 NaN         NaN          NaN          NaN
# 27          NaN                 NaN         NaN          NaN          NaN
# 28          NaN                 NaN         NaN          NaN          NaN
# 29          NaN                 NaN         NaN          NaN          NaN
# 30          NaN                 NaN         NaN          NaN          NaN
# 31          NaN                 NaN         NaN          NaN          NaN
# 32          NaN                 NaN         NaN          NaN          NaN
# 33          NaN                 NaN         NaN          NaN          NaN
# 34          NaN                 NaN         NaN          NaN          NaN
# 35          NaN                 NaN         NaN          NaN          NaN
#
#          Unnamed: 17 Unnamed: 18  Unnamed: 19
# 0              Total         NaN          NaN
# 1   Estimate\n('000)           %       95% CI
# 2                NaN         NaN          NaN
# 3             6726.6        84.5  (83.8–85.2)
# 4             6399.6        80.4  (79.7–81.1)
# 5             5211.3        65.5  (64.7–66.2)
# 6             1188.8        14.9  (14.2–15.7)
# 7                327         4.1    (3.7–4.5)
# 8             1231.4        15.5  (14.8–16.1)
# 9               7960         100          . .
# 10               NaN         NaN          NaN
# 11            6168.1        75.9  (75.2–76.6)
# 12            5840.6        71.9  (71.2–72.6)
# 13            3061.8        37.7  (36.8–38.6)
# 14            2777.9        34.2  (33.3–35.0)
# 15             329.3         4.1    (3.7–4.4)
# 16            1956.7        24.1  (23.4–24.8)
# 17            8122.9         100          . .
# 18               NaN         NaN          NaN
# 19           12895.2        80.2  (79.7–80.6)
# 20           12239.8        76.1  (75.7–76.5)
# 21            8272.6        51.4  (50.7–52.1)
# 22            3969.6        24.7  (24.1–25.3)
# 23             655.4         4.1    (3.8–4.3)
# 24            3186.3        19.8  (19.4–20.3)
# 25           16081.9         100          . .
# 26               NaN         NaN          NaN
# 27               NaN         NaN          NaN
# 28               NaN         NaN          NaN
# 29               NaN         NaN          NaN
# 30               NaN         NaN          NaN
# 31               NaN         NaN          NaN
# 32               NaN         NaN          NaN
# 33               NaN         NaN          NaN
# 34               NaN         NaN          NaN
# 35               NaN         NaN          NaN

# %% [markdown]
# Table EMPL1 in the AIHW data contains population of people aged 15-64 living in households, by labour force and employment status, disability status and sex in 2018.

# %% [markdown]
# ## Transform data
#
# In the process of data transforming, we extract 'employment status', 'estimated number of people ('000)', and 'proportion (%)' data for people with disability.

# %%
# extract rows and columns
extract_columns = ['Unnamed: 0', 'Unnamed: 9', 'Unnamed: 10']
extracted_df = df[extract_columns]

extracted_df.rename(columns={"Unnamed: 0": "employment status", 
                             "Unnamed: 9": "estimated number of people ('000)", 
                             "Unnamed: 10": "proportion(%)"}, inplace=True) #rename columns
extracted_df = extracted_df.iloc[19:26]
extracted_df
# Out:
# /Users/jihoonwoo/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#              employment status estimated number of people ('000) proportion(%)
# 19      In the labour force(d)                            1098.6          53.4
# 20                 Employed(e)                             984.2          47.8
# 21  Employed working full-time                             581.8          28.3
# 22  Employed working part-time                             402.8          19.6
# 23                  Unemployed                             112.7           5.5
# 24  Not in the labour force(f)                             958.5          46.6
# 25                       Total                            2057.5           100

# %% [markdown]
# The transformed data contains number/proportion size of people with a disability by employment status.

# %% [markdown]
# ## Save the result

# %%
extracted_df.to_csv(output_file, sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## Conclusion
#
# In this Jupyter notebook, we demonstrated how to access and transform data from ABS (https://www.abs.gov.au/). The transformed data contains number/proportion size of people with a disability by employment status in 2018.

# %% [markdown]
# ## References
#
# [1] AIHW. People with disability in Australia, Data tables: Employment supplementary data tables, 2020, Australian Institute of Health and Welfare, [Dataset] Available: https://www.aihw.gov.au/reports/disability/people-with-disability-in-australia/data. [Accessed: January 4, 2021].
